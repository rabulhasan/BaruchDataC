# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# replace the file path with your own CSV file path
csv_file = "C:/Users/rhlin/OneDrive - The City University of New York (1)/Untitled Folder/train_anonimized.csv"

# read the CSV file using pandas
df = pd.read_csv(csv_file)

# get the number of rows and columns in the DataFrame
print("Shape of DataFrame:", df.shape)

# get the column names
print("Column Names:", df.columns)

# view the first few rows of the DataFrame
print("First Few Rows of DataFrame:")
df.head()
# Out:
# Shape of DataFrame: (25163, 4)
# Column Names: Index(['NAICS_DESC', 'DATE', 'REVENUE', 'anonimized_name'], dtype='object')
# First Few Rows of DataFrame:
# Summary Statistics:
#              REVENUE
# count   25163.000000
# mean     6315.247387
# std      9355.128860
# min         0.000000
# 25%      1444.500000
# 50%      3962.000000
# 75%      8113.500000
# max    286148.000000
# <AxesSubplot:xlabel='anonimized_name', ylabel='count'>

# %%
# get summary statistics for the numeric columns
print("Summary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#              REVENUE
# count   25163.000000
# mean     6315.247387
# std      9355.128860
# min         0.000000
# 25%      1444.500000
# 50%      3962.000000
# 75%      8113.500000
# max    286148.000000

# %%
# create a histogram of a numeric column
sns.histplot(data=df, x="REVENUE")
plt.show()

# %%
sns.heatmap(data=df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=df, x="REVENUE", y="anonimized_name")
# Out:
# <AxesSubplot:xlabel='REVENUE', ylabel='anonimized_name'>

# %%
sns.boxplot(data=df, x="anonimized_name", y="REVENUE")
# Out:
# <AxesSubplot:xlabel='anonimized_name', ylabel='REVENUE'>

# %%
sns.countplot(data=df, x="anonimized_name")
# Out:
# <AxesSubplot:xlabel='anonimized_name', ylabel='count'>
